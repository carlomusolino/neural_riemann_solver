# %%
import torch 
import pickle 

import matplotlib.pyplot as plt

# %%
import os 

path = '../models/2_layers_64_neurons/131072_samples/42/prob_1_fo'

with open(os.path.join(path,'results.pkl'),'rb') as f:
    d = pickle.load(f)

# %%
list(d[800])
# Out:
# ['ml', 'x']

# %%
plt.plot(d[800]['x'], d[800]['ml']['rho'])

# %%
with open('/mnt/rafast/musolino/ml_riemann/models_new/2_layers_64_neurons/131072_samples/42/prob_1_fo/results.pkl','rb') as f:
    d1 = pickle.load(f)

# %%
plt.plot(d[800]['x'], )
plt.plot(d1[800]['x'], )

# %%
import numpy as np
np.amax(d1[800]['ml']['rho']-d[800]['ml']['rho'])
# Out:
# 0.0
